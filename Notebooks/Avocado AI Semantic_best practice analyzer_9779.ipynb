# %% [markdown]
# ## Best Practice Analyzer
#
# When you run this notebook, the [Best Practice Analyzer](https://learn.microsoft.com/python/api/semantic-link-sempy/sempy.fabric?view=semantic-link-python#sempy-fabric-run-model-bpa) (BPA) will offer tips to improve the design and performance of your semantic model.
#
# By default, the BPA checks a set of 60+ rules against your semantic model and summarizes the results. These rules come from experts within Microsoft and the Fabric Community.
#
# You’ll get suggestions for improvement in five categories: Performance, DAX Expressions, Error Prevention, Maintenance, and Formatting.
#
# ### Powering this feature: Semantic Link
# This notebook leverages [Semantic Link](https://learn.microsoft.com/fabric/data-science/semantic-link-overview), a python library which lets you optimize Fabric items for performance, memory and cost. The "[run_model_bpa](https://learn.microsoft.com/python/api/semantic-link-sempy/sempy.fabric?view=semantic-link-python#sempy-fabric-run-model-bpa)" function used in this notebook is just one example of the useful [functions]((https://learn.microsoft.com/python/api/semantic-link-sempy/sempy.fabric)) which Semantic Link offers.
#
# You can find more [functions](https://github.com/microsoft/semantic-link-labs#featured-scenarios) and [helper notebooks](https://github.com/microsoft/semantic-link-labs/tree/main/notebooks) in [Semantic Link Labs](https://github.com/microsoft/semantic-link-labs), a Python library that extends Semantic Link's capabilities to automate technical tasks.
#
# ### Low-code solutions for data tasks
# You don't have to be a Python expert to use Semantic Link or Semantic Link Labs. Many functions can be used simply by entering your parameters and running the notebook.

# %% [markdown]
# #### Import the Semantic Link library

# %%
# Ensure semantic-link>=0.9.2 is installed
from packaging.version import Version
from importlib.metadata import version

sempy_version = version('semantic-link-sempy')

if Version(sempy_version) < Version("0.9.2"):
    get_ipython().run_line_magic('pip', 'install semantic-link==0.9.2')
# Out:
# StatementMeta(, a345467d-8ef5-455e-b3df-17c005533b90, 3, Finished, Available, Finished)
# Collecting semantic-link==0.9.2
#   Downloading semantic_link-0.9.2-py3-none-any.whl.metadata (9.5 kB)
# Collecting semantic-link-sempy==0.9.2 (from semantic-link==0.9.2)
#   Downloading semantic_link_sempy-0.9.2-py3-none-any.whl.metadata (9.4 kB)
# Collecting semantic-link-functions-geopandas==0.9.2 (from semantic-link==0.9.2)
#   Downloading semantic_link_functions_geopandas-0.9.2-py3-none-any.whl.metadata (1.9 kB)
# Collecting semantic-link-functions-holidays==0.9.2 (from semantic-link==0.9.2)
#   Downloading semantic_link_functions_holidays-0.9.2-py3-none-any.whl.metadata (1.8 kB)
# Collecting semantic-link-functions-meteostat==0.9.2 (from semantic-link==0.9.2)
#   Downloading semantic_link_functions_meteostat-0.9.2-py3-none-any.whl.metadata (2.0 kB)
# Collecting semantic-link-functions-phonenumbers==0.9.2 (from semantic-link==0.9.2)
#   Downloading semantic_link_functions_phonenumbers-0.9.2-py3-none-any.whl.metadata (1.8 kB)
# Collecting semantic-link-functions-validators==0.9.2 (from semantic-link==0.9.2)
#   Downloading semantic_link_functions_validators-0.9.2-py3-none-any.whl.metadata (1.8 kB)
# Collecting geopandas (from semantic-link-functions-geopandas==0.9.2->semantic-link==0.9.2)
#   Downloading geopandas-1.0.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting folium (from semantic-link-functions-geopandas==0.9.2->semantic-link==0.9.2)
#   Downloading folium-0.19.5-py2.py3-none-any.whl.metadata (4.1 kB)
# Collecting mapclassify (from semantic-link-functions-geopandas==0.9.2->semantic-link==0.9.2)
#   Downloading mapclassify-2.8.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: holidays in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-functions-holidays==0.9.2->semantic-link==0.9.2) (0.48)
# Collecting meteostat (from semantic-link-functions-meteostat==0.9.2->semantic-link==0.9.2)
#   Downloading meteostat-1.6.8-py3-none-any.whl.metadata (4.6 kB)
# Collecting phonenumbers (from semantic-link-functions-phonenumbers==0.9.2->semantic-link==0.9.2)
#   Downloading phonenumbers-9.0.2-py2.py3-none-any.whl.metadata (11 kB)
# Collecting validators (from semantic-link-functions-validators==0.9.2->semantic-link==0.9.2)
#   Downloading validators-0.34.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: clr-loader>=0.2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.9.2->semantic-link==0.9.2) (0.2.5)
# Requirement already satisfied: graphviz>=0.20.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.9.2->semantic-link==0.9.2) (0.20.1)
# Requirement already satisfied: pyarrow>=12.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.9.2->semantic-link==0.9.2) (14.0.2)
# Requirement already satisfied: pythonnet>=3.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.9.2->semantic-link==0.9.2) (3.0.1)
# Requirement already satisfied: scikit-learn>=1.2.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.9.2->semantic-link==0.9.2) (1.2.2)
# Requirement already satisfied: setuptools>=68.2.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.9.2->semantic-link==0.9.2) (68.2.2)
# Requirement already satisfied: tqdm>=4.65.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.9.2->semantic-link==0.9.2) (4.65.0)
# Requirement already satisfied: rich>=13.3.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy==0.9.2->semantic-link==0.9.2) (13.3.5)
# Requirement already satisfied: cffi>=1.13 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from clr-loader>=0.2.5->semantic-link-sempy==0.9.2->semantic-link==0.9.2) (1.16.0)
# Requirement already satisfied: numpy>=1.16.6 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pyarrow>=12.0.1->semantic-link-sempy==0.9.2->semantic-link==0.9.2) (1.26.4)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from rich>=13.3.5->semantic-link-sempy==0.9.2->semantic-link==0.9.2) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from rich>=13.3.5->semantic-link-sempy==0.9.2->semantic-link==0.9.2) (2.15.1)
# Requirement already satisfied: scipy>=1.3.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy==0.9.2->semantic-link==0.9.2) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy==0.9.2->semantic-link==0.9.2) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from scikit-learn>=1.2.2->semantic-link-sempy==0.9.2->semantic-link==0.9.2) (2.2.0)
# Collecting branca>=0.6.0 (from folium->semantic-link-functions-geopandas==0.9.2->semantic-link==0.9.2)
#   Downloading branca-0.8.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jinja2>=2.9 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from folium->semantic-link-functions-geopandas==0.9.2->semantic-link==0.9.2) (3.1.3)
# Requirement already satisfied: requests in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from folium->semantic-link-functions-geopandas==0.9.2->semantic-link==0.9.2) (2.31.0)
# Requirement already satisfied: xyzservices in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from folium->semantic-link-functions-geopandas==0.9.2->semantic-link==0.9.2) (2022.9.0)
# Collecting pyogrio>=0.7.2 (from geopandas->semantic-link-functions-geopandas==0.9.2->semantic-link==0.9.2)
#   Downloading pyogrio-0.10.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Requirement already satisfied: packaging in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from geopandas->semantic-link-functions-geopandas==0.9.2->semantic-link==0.9.2) (23.1)
# Requirement already satisfied: pandas>=1.4.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from geopandas->semantic-link-functions-geopandas==0.9.2->semantic-link==0.9.2) (2.1.4)
# Collecting pyproj>=3.3.0 (from geopandas->semantic-link-functions-geopandas==0.9.2->semantic-link==0.9.2)
#   Downloading pyproj-3.7.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (31 kB)
# Collecting shapely>=2.0.0 (from geopandas->semantic-link-functions-geopandas==0.9.2->semantic-link==0.9.2)
#   Downloading shapely-2.0.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: python-dateutil in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from holidays->semantic-link-functions-holidays==0.9.2->semantic-link==0.9.2) (2.8.2)
# Requirement already satisfied: networkx>=2.7 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from mapclassify->semantic-link-functions-geopandas==0.9.2->semantic-link==0.9.2) (3.1)
# Requirement already satisfied: pytz in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from meteostat->semantic-link-functions-meteostat==0.9.2->semantic-link==0.9.2) (2023.3.post1)
# Requirement already satisfied: pycparser in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from cffi>=1.13->clr-loader>=0.2.5->semantic-link-sempy==0.9.2->semantic-link==0.9.2) (2.21)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jinja2>=2.9->folium->semantic-link-functions-geopandas==0.9.2->semantic-link==0.9.2) (2.1.3)
# Requirement already satisfied: mdurl~=0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=13.3.5->semantic-link-sempy==0.9.2->semantic-link==0.9.2) (0.1.0)
# Requirement already satisfied: tzdata>=2022.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas>=1.4.0->geopandas->semantic-link-functions-geopandas==0.9.2->semantic-link==0.9.2) (2023.3)
# Requirement already satisfied: certifi in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pyogrio>=0.7.2->geopandas->semantic-link-functions-geopandas==0.9.2->semantic-link==0.9.2) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from python-dateutil->holidays->semantic-link-functions-holidays==0.9.2->semantic-link==0.9.2) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests->folium->semantic-link-functions-geopandas==0.9.2->semantic-link==0.9.2) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests->folium->semantic-link-functions-geopandas==0.9.2->semantic-link==0.9.2) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests->folium->semantic-link-functions-geopandas==0.9.2->semantic-link==0.9.2) (2.1.0)
# Downloading semantic_link-0.9.2-py3-none-any.whl (9.9 kB)
# Downloading semantic_link_functions_geopandas-0.9.2-py3-none-any.whl (4.0 kB)
# Downloading semantic_link_functions_holidays-0.9.2-py3-none-any.whl (4.2 kB)
# Downloading semantic_link_functions_meteostat-0.9.2-py3-none-any.whl (4.5 kB)
# Downloading semantic_link_functions_phonenumbers-0.9.2-py3-none-any.whl (4.3 kB)
# Downloading semantic_link_functions_validators-0.9.2-py3-none-any.whl (4.7 kB)
# Downloading semantic_link_sempy-0.9.2-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 104.5 MB/s eta 0:00:00
# Downloading folium-0.19.5-py2.py3-none-any.whl (110 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.9/110.9 kB 44.5 MB/s eta 0:00:00
# Downloading geopandas-1.0.1-py3-none-any.whl (323 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.6/323.6 kB 89.6 MB/s eta 0:00:00
# Downloading mapclassify-2.8.1-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 kB 22.5 MB/s eta 0:00:00
# Downloading meteostat-1.6.8-py3-none-any.whl (31 kB)
# Downloading phonenumbers-9.0.2-py2.py3-none-any.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 207.5 MB/s eta 0:00:00
# Downloading validators-0.34.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 14.6 MB/s eta 0:00:00
# Downloading branca-0.8.1-py3-none-any.whl (26 kB)
# Downloading pyogrio-0.10.0-cp311-cp311-manylinux_2_28_x86_64.whl (24.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 145.5 MB/s eta 0:00:0000:0100:01
# Downloading pyproj-3.7.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 207.0 MB/s eta 0:00:0000:01
# Downloading shapely-2.0.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 190.9 MB/s eta 0:00:00
# Installing collected packages: phonenumbers, validators, shapely, pyproj, pyogrio, branca, meteostat, mapclassify, geopandas, folium, semantic-link-sempy, semantic-link-functions-validators, semantic-link-functions-phonenumbers, semantic-link-functions-meteostat, semantic-link-functions-holidays, semantic-link-functions-geopandas, semantic-link
#   Attempting uninstall: semantic-link-sempy
#     Found existing installation: semantic-link-sempy 0.9.0
#     Uninstalling semantic-link-sempy-0.9.0:
#       Successfully uninstalled semantic-link-sempy-0.9.0
# Successfully installed branca-0.8.1 folium-0.19.5 geopandas-1.0.1 mapclassify-2.8.1 meteostat-1.6.8 phonenumbers-9.0.2 pyogrio-0.10.0 pyproj-3.7.1 semantic-link-0.9.2 semantic-link-functions-geopandas-0.9.2 semantic-link-functions-holidays-0.9.2 semantic-link-functions-meteostat-0.9.2 semantic-link-functions-phonenumbers-0.9.2 semantic-link-functions-validators-0.9.2 semantic-link-sempy-0.9.2 shapely-2.0.7 validators-0.34.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import sempy.fabric as fabric

dataset = "Avocado AI Semantic" # Enter the name or ID of the semantic model
workspace = "The Microsoft Data + AI Kenya Hack" # Enter the workspace name or ID in which the semantic model exists
# Out:
# StatementMeta(, a345467d-8ef5-455e-b3df-17c005533b90, 5, Finished, Available, Finished)

# %% [markdown]
# #### Run the Best Practice Analyzer on your semantic model

# %%
fabric.run_model_bpa(dataset=dataset, workspace=workspace)
# Out:
# StatementMeta(, a345467d-8ef5-455e-b3df-17c005533b90, 6, Finished, Available, Finished)
#     <style>
#         .tab { overflow: hidden; border: 1px solid #ccc; background-color: #f1f1f1; }
#         .tab button { background-color: inherit; float: left; border: none; outline: none; cursor: pointer; padding: 14px 16px; transition: 0.3s; }
#         .tab button:hover { background-color: #ddd; }
#         .tab button.active { background-color: #ccc; }
#         .tabcontent { display: none; padding: 6px 12px; border: 1px solid #ccc; border-top: none; }
#         .tabcontent.active { display: block; }
#         .tooltip { position: relative; display: inline-block; }
#         .tooltip .tooltiptext { visibility: hidden; width: 300px; background-color: #555; color: #fff; text-align: center; border-radius: 6px; padding: 5px; position: absolute; z-index: 1; bottom: 125%; left: 50%; margin-left: -110px; opacity: 0; transition: opacity 0.3s; }
#         .tooltip:hover .tooltiptext { visibility: visible; opacity: 1; }
#     </style>
#     <div class="tab"><button class="tablinks active" onclick="openTab(event, 'tab0')"><b>Formatting</b><br/>⚠️ (31) + ℹ️ (23)</button><button class="tablinks " onclick="openTab(event, 'tab1')"><b>Maintenance</b><br/>ℹ️ (43) + ⚠️ (4)</button><button class="tablinks " onclick="openTab(event, 'tab2')"><b>Performance</b><br/>⚠️ (16)</button></div><div id="tab0" class="tabcontent active"><table border="1"><tr><th>Rule Name</th><th>Object Type</th><th>Object Name</th><th>Severity</th></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)">Do not summarize numeric columns<span class="tooltiptext">Numeric columns (integer, decimal, double) should have their SummarizeBy property set to "None" to avoid accidental summation in Power BI (create measures instead).</span></td><td>Column</td><td>'avocado_conditions_silver'[Altitude]</td><td style="text-align: center;">⚠️</td></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)">Do not summarize numeric columns<span class="tooltiptext">Numeric columns (integer, decimal, double) should have their SummarizeBy property set to "None" to avoid accidental summation in Power BI (create measures instead).</span></td><td>Column</td><td>'avocado_conditions_silver'[Annual_Rainfall]</td><td style="text-align: center;">⚠️</td></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)">Do not summarize numeric columns<span class="tooltiptext">Numeric columns (integer, decimal, double) should have their SummarizeBy property set to "None" to avoid accidental summation in Power BI (create measures instead).</span></td><td>Column</td><td>'avocado_conditions_silver'[Avg_Temperature]</td><td style="text-align: center;">⚠️</td></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)">Do not summarize numeric columns<span class="tooltiptext">Numeric columns (integer, decimal, double) should have their SummarizeBy property set to "None" to avoid accidental summation in Power BI (create measures instead).</span></td><td>Column</td><td>'avocado_conditions_silver'[Soil_pH]</td><td style="text-align: center;">⚠️</td></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)">Do not summarize numeric columns<span class="tooltiptext">Numeric columns (integer, decimal, double) should have their SummarizeBy property set to "None" to avoid accidental summation in Power BI (create measures instead).</span></td><td>Column</td><td>'avocado_conditions_silver'[Year]</td><td style="text-align: center;">⚠️</td></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)">Do not summarize numeric columns<span class="tooltiptext">Numeric columns (integer, decimal, double) should have their SummarizeBy property set to "None" to avoid accidental summation in Power BI (create measures instead).</span></td><td>Column</td><td>'avocado_conditions_silver'[Yield_per_Hectare]</td><td style="text-align: center;">⚠️</td></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)">Do not summarize numeric columns<span class="tooltiptext">Numeric columns (integer, decimal, double) should have their SummarizeBy property set to "None" to avoid accidental summation in Power BI (create measures instead).</span></td><td>Column</td><td>'dbo_Kenya_Month_Avocado_Sales'[Average_Price]</td><td style="text-align: center;">⚠️</td></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)">Do not summarize numeric columns<span class="tooltiptext">Numeric columns (integer, decimal, double) should have their SummarizeBy property set to "None" to avoid accidental summation in Power BI (create measures instead).</span></td><td>Column</td><td>'dbo_Kenya_Month_Avocado_Sales'[Domestic_Consumption]</td><td style="text-align: center;">⚠️</td></tr><tr><td class="tooltip" onmouseover="adjustTooltipPosition(event)">Do not summarize numeric columns<span class="tooltiptext">Numeric columns (integer, decimal, double) should have their SummarizeBy property set to "None"  ...

# %% [markdown]
# #### Learn more about notebooks in Fabric
# Notebooks in Fabric empower you to use code and low-code solutions for a wide range of data analytics and data engineering tasks such as data transformation, pipeline automation, and machine learning modeling.
#
# * To edit this notebook, switch the mode from **Run** only to **Edit** or **Develop**.
# * You can safely delete this notebook after running it. This won’t affect your semantic model.
#
#
# For more information on capabilities and features, check out [Microsoft Fabric Notebook Documentation](https://learn.microsoft.com/fabric/data-engineering/how-to-use-notebook).
